# %% [markdown]
# <a href="https://www.kaggle.com/code/guisira/nlp-with-disaster-tweets-by-using-lstm?scriptVersionId=92523851" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/glove6b100dtxt/glove.6B.100d.txt
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %% [markdown]
# ## Import library

# %%
import csv
import string 
import random
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from scipy.stats import linregress
from nltk import corpus
import re
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.stem.snowball import SnowballStemmer
import seaborn as sns
from collections import Counter
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Sentiment Extaction-Analysis EDA

# %%
df_train = pd.read_csv("/kaggle/input/nlp-getting-started/train.csv")

# %%
print(df_train.shape)
# Out:
# (7613, 5)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
df_train = df_train[["id","text","target"]]

# %%
df_train.head()
# Out:
#    id                                               text  target
# 0   1  Our Deeds are the Reason of this #earthquake M...       1
# 1   4             Forest fire near La Ronge Sask. Canada       1
# 2   5  All residents asked to 'shelter in place' are ...       1
# 3   6  13,000 people receive #wildfires evacuation or...       1
# 4   7  Just got sent this photo from Ruby #Alaska as ...       1

# %%
temp = df_train.groupby('target').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp
# Out:
#    target  text
# 0       0  4342
# 1       1  3271

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='target',data=df_train)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
def clean_text(text) :
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df_train['text'] = df_train['text'].apply(lambda x:clean_text(x))

# %%
df_train['temp_list'] = df_train['text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(10))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_60442_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_60442_row1_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_60442_row2_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_60442_row3_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_60442_row4_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_60442_row5_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_60442_row6_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_60442_row7_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_60442_row8_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_60442_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_60442_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60442_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60442_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_60442_row0_col1" class="data row0 col1" >3248</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60442_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_60442_row1_col1" class="data row1 col1" >2167</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60442_row2_col0" class="data row2 col0" >in</td>
#       <td id="T_60442_row2_col1" class="data row2 col1" >1971</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60442_row3_col0" class="data row3 col0" >to</td>
#       <td id="T_60442_row3_col1" class="data row3 col1" >1943</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60442_row4_col0" class="data row4 col0" >of</td>
#       <td id="T_60442_row4_col1" class="data row4 col1" >1821</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_60442_row5_col0" class="data row5 col0" >and</td>
#       <td id="T_60442_row5_col1" class="data row5 col1" >1410</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_60442_row6_col0" class="data row6 col0" >i</td>
#       <td id="T_60442_row6_col1" class="data row6 col1" >1363</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_60442_row7_col0" class="data row7 col0" >is</td>
#       <td id="T_60442_row7_col1" class="data row7 col1" >942</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_60442_row8_col0" class="data row8 col0" >for</td>
#       <td id="T_60442_row8_col1" class="data row8 col1" >889</td>
#     </tr>
#     <tr>
#       <th id="T_60442_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_60442_row9_col0" class="data row9 col0" >on</td>
#       <td id="T_60442_row9_col1" class="data row9 col1" >850</td>
#     </tr>
#   </tbody>
# </table>

# %%
def remove_stopword(x):
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    return [word for word in x if not word in set(all_stopwords)]

df_train['temp_list'] = df_train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_e0839_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_e0839_row1_col1 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_e0839_row2_col1 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_e0839_row3_col1 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_e0839_row4_col1 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_e0839_row5_col1 {
#   background-color: #8e8ac0;
#   color: #f1f1f1;
# }
# #T_e0839_row6_col1 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_e0839_row7_col1 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_e0839_row8_col1 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_e0839_row9_col1 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_e0839_row10_col1 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_e0839_row11_col1 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_e0839_row12_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_e0839_row13_col1 {
#   background-color: #e5e4f0;
#   color: #000000;
# }
# #T_e0839_row14_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_e0839_row15_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_e0839_row16_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_e0839_row17_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_e0839_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_e0839_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0839_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e0839_row0_col0" class="data row0 col0" >amp</td>
#       <td id="T_e0839_row0_col1" class="data row0 col1" >298</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e0839_row1_col0" class="data row1 col0" >im</td>
#       <td id="T_e0839_row1_col1" class="data row1 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e0839_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_e0839_row2_col1" class="data row2 col1" >293</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e0839_row3_col0" class="data row3 col0" >fire</td>
#       <td id="T_e0839_row3_col1" class="data row3 col1" >248</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e0839_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_e0839_row4_col1" class="data row4 col1" >228</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e0839_row5_col0" class="data row5 col0" >new</td>
#       <td id="T_e0839_row5_col1" class="data row5 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e0839_row6_col0" class="data row6 col0" >via</td>
#       <td id="T_e0839_row6_col1" class="data row6 col1" >220</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e0839_row7_col0" class="data row7 col0" >people</td>
#       <td id="T_e0839_row7_col1" class="data row7 col1" >196</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e0839_row8_col0" class="data row8 col0" >one</td>
#       <td id="T_e0839_row8_col1" class="data row8 col1" >191</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e0839_row9_col0" class="data row9 col0" >dont</td>
#       <td id="T_e0839_row9_col1" class="data row9 col1" >189</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_e0839_row10_col0" class="data row10 col0" >news</td>
#       <td id="T_e0839_row10_col1" class="data row10 col1" >185</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_e0839_row11_col0" class="data row11 col0" >us</td>
#       <td id="T_e0839_row11_col1" class="data row11 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_e0839_row12_col0" class="data row12 col0" >video</td>
#       <td id="T_e0839_row12_col1" class="data row12 col1" >158</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_e0839_row13_col0" class="data row13 col0" >emergency</td>
#       <td id="T_e0839_row13_col1" class="data row13 col1" >156</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_e0839_row14_col0" class="data row14 col0" >disaster</td>
#       <td id="T_e0839_row14_col1" class="data row14 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_e0839_row15_col0" class="data row15 col0" >police</td>
#       <td id="T_e0839_row15_col1" class="data row15 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_e0839_row16_col0" class="data row16 col0" >would</td>
#       <td id="T_e0839_row16_col1" class="data row16 col1" >129</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_e0839_row17_col0" class="data row17 col0" >still</td>
#       <td id="T_e0839_row17_col1" class="data row17 col1" >128</td>
#     </tr>
#     <tr>
#       <th id="T_e0839_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_e0839_row18_col0" class="data row18 col0" >body</td>
#       <td id="T_e0839_row18_col1" class="data row18 col1" >124</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c37c4eca-5ebf-4c2a-a270-01774dea9e4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c37c4eca-5ebf-4c2a-a270-01774dea9e4b")) {                    Plotly.newPlot(                        "c37c4eca-5ebf-4c2a-a270-01774dea9e4b",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["amp","body","disaster","dont","emergency","fire","get","im","new","news","not","one","people","police","still","us","via","video","would"],"labels":["amp","body","disaster","dont","emergency","fire","get","im","new","news","not","one","people","police","still","us","via","video","would"],"name":"","parents":["","","","","","","","","","","","","","","","","","",""],"values":[298,124,150,189,156,248,228,294,223,185,293,191,196,137,128,162,220,158,129],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlin ...

# %%
real_disaster = df_train[df_train['target']== 0]
fake_disaster = df_train[df_train['target']== 1]

# %%
top = Counter([item for sublist in real_disaster['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive = temp_positive.iloc[0:,:]
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c3dcb_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c3dcb_row1_col1 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_c3dcb_row2_col1 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_c3dcb_row3_col1 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_c3dcb_row4_col1 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_c3dcb_row5_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_c3dcb_row6_col1 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_c3dcb_row7_col1 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_c3dcb_row8_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_c3dcb_row9_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_c3dcb_row10_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_c3dcb_row11_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_c3dcb_row12_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_c3dcb_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_c3dcb_row14_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_c3dcb_row15_col1, #T_c3dcb_row16_col1, #T_c3dcb_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_c3dcb_row18_col1, #T_c3dcb_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c3dcb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3dcb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3dcb_row0_col0" class="data row0 col0" >like</td>
#       <td id="T_c3dcb_row0_col1" class="data row0 col1" >252</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3dcb_row1_col0" class="data row1 col0" >im</td>
#       <td id="T_c3dcb_row1_col1" class="data row1 col1" >239</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3dcb_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_c3dcb_row2_col1" class="data row2 col1" >201</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3dcb_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_c3dcb_row3_col1" class="data row3 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3dcb_row4_col0" class="data row4 col0" >new</td>
#       <td id="T_c3dcb_row4_col1" class="data row4 col1" >168</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3dcb_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_c3dcb_row5_col1" class="data row5 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3dcb_row6_col0" class="data row6 col0" >dont</td>
#       <td id="T_c3dcb_row6_col1" class="data row6 col1" >139</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3dcb_row7_col0" class="data row7 col0" >one</td>
#       <td id="T_c3dcb_row7_col1" class="data row7 col1" >126</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3dcb_row8_col0" class="data row8 col0" >body</td>
#       <td id="T_c3dcb_row8_col1" class="data row8 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3dcb_row9_col0" class="data row9 col0" >via</td>
#       <td id="T_c3dcb_row9_col1" class="data row9 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c3dcb_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_c3dcb_row10_col1" class="data row10 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c3dcb_row11_col0" class="data row11 col0" >people</td>
#       <td id="T_c3dcb_row11_col1" class="data row11 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c3dcb_row12_col0" class="data row12 col0" >video</td>
#       <td id="T_c3dcb_row12_col1" class="data row12 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c3dcb_row13_col0" class="data row13 col0" >love</td>
#       <td id="T_c3dcb_row13_col1" class="data row13 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c3dcb_row14_col0" class="data row14 col0" >back</td>
#       <td id="T_c3dcb_row14_col1" class="data row14 col1" >84</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c3dcb_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_c3dcb_row15_col1" class="data row15 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c3dcb_row16_col0" class="data row16 col0" >know</td>
#       <td id="T_c3dcb_row16_col1" class="data row16 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c3dcb_row17_col0" class="data row17 col0" >got</td>
#       <td id="T_c3dcb_row17_col1" class="data row17 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c3dcb_row18_col0" class="data row18 col0" >cant</td>
#       <td id="T_c3dcb_row18_col1" class="data row18 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_c3dcb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c3dcb_row19_col0" class="data row19 col0" >us</td>
#       <td id="T_c3dcb_row19_col1" class="data row19 col1" >81</td>
#     </tr>
#   </tbody>
# </table>

# %%
top = Counter([item for sublist in fake_disaster['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_624db_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_624db_row1_col1 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_624db_row2_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_624db_row3_col1 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_624db_row4_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_624db_row5_col1 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_624db_row6_col1, #T_624db_row7_col1 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_624db_row8_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_624db_row9_col1, #T_624db_row10_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_624db_row11_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_624db_row12_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_624db_row13_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_624db_row14_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_624db_row15_col1, #T_624db_row16_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_624db_row17_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_624db_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_624db_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_624db_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_624db_row0_col0" class="data row0 col0" >news</td>
#       <td id="T_624db_row0_col1" class="data row0 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_624db_row1_col0" class="data row1 col0" >via</td>
#       <td id="T_624db_row1_col1" class="data row1 col1" >121</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_624db_row2_col0" class="data row2 col0" >disaster</td>
#       <td id="T_624db_row2_col1" class="data row2 col1" >116</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_624db_row3_col0" class="data row3 col0" >california</td>
#       <td id="T_624db_row3_col1" class="data row3 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_624db_row4_col0" class="data row4 col0" >suicide</td>
#       <td id="T_624db_row4_col1" class="data row4 col1" >110</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_624db_row5_col0" class="data row5 col0" >amp</td>
#       <td id="T_624db_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_624db_row6_col0" class="data row6 col0" >people</td>
#       <td id="T_624db_row6_col1" class="data row6 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_624db_row7_col0" class="data row7 col0" >police</td>
#       <td id="T_624db_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_624db_row8_col0" class="data row8 col0" >killed</td>
#       <td id="T_624db_row8_col1" class="data row8 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_624db_row9_col0" class="data row9 col0" >not</td>
#       <td id="T_624db_row9_col1" class="data row9 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_624db_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_624db_row10_col1" class="data row10 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_624db_row11_col0" class="data row11 col0" >hiroshima</td>
#       <td id="T_624db_row11_col1" class="data row11 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_624db_row12_col0" class="data row12 col0" >fires</td>
#       <td id="T_624db_row12_col1" class="data row12 col1" >84</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_624db_row13_col0" class="data row13 col0" >storm</td>
#       <td id="T_624db_row13_col1" class="data row13 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_624db_row14_col0" class="data row14 col0" >crash</td>
#       <td id="T_624db_row14_col1" class="data row14 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_624db_row15_col0" class="data row15 col0" >us</td>
#       <td id="T_624db_row15_col1" class="data row15 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_624db_row16_col0" class="data row16 col0" >families</td>
#       <td id="T_624db_row16_col1" class="data row16 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_624db_row17_col0" class="data row17 col0" >train</td>
#       <td id="T_624db_row17_col1" class="data row17 col1" >79</td>
#     </tr>
#     <tr>
#       <th id="T_624db_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_624db_row18_col0" class="data row18 col0" >emergency</td>
#       <td id="T_624db_row18_col1" class="data row18 col1" >75</td>
#     </tr>
#   </tbody>
# </table>

# %%
raw_text = [word for word_list in df_train['temp_list'] for word in word_list]

# %%
def words_unique(target,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in df_train[df_train.target != target]['temp_list']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in df_train[df_train.target == target]['temp_list']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %%
Unique_true= words_unique(1, 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_true.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style type="text/css">
# #T_38e64_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_38e64_row1_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_38e64_row2_col1 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_38e64_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_38e64_row4_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_38e64_row5_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_38e64_row6_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_38e64_row7_col1 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_38e64_row8_col1, #T_38e64_row9_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_38e64_row10_col1, #T_38e64_row11_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_38e64_row12_col1, #T_38e64_row13_col1, #T_38e64_row14_col1, #T_38e64_row15_col1, #T_38e64_row16_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_38e64_row17_col1, #T_38e64_row18_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_38e64_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_38e64_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38e64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38e64_row0_col0" class="data row0 col0" >northern</td>
#       <td id="T_38e64_row0_col1" class="data row0 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38e64_row1_col0" class="data row1 col0" >legionnaires</td>
#       <td id="T_38e64_row1_col1" class="data row1 col1" >62</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38e64_row2_col0" class="data row2 col0" >debris</td>
#       <td id="T_38e64_row2_col1" class="data row2 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38e64_row3_col0" class="data row3 col0" >severe</td>
#       <td id="T_38e64_row3_col1" class="data row3 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38e64_row4_col0" class="data row4 col0" >derailment</td>
#       <td id="T_38e64_row4_col1" class="data row4 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38e64_row5_col0" class="data row5 col0" >migrants</td>
#       <td id="T_38e64_row5_col1" class="data row5 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38e64_row6_col0" class="data row6 col0" >investigators</td>
#       <td id="T_38e64_row6_col1" class="data row6 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38e64_row7_col0" class="data row7 col0" >mosque</td>
#       <td id="T_38e64_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38e64_row8_col0" class="data row8 col0" >pkk</td>
#       <td id="T_38e64_row8_col1" class="data row8 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38e64_row9_col0" class="data row9 col0" >detonated</td>
#       <td id="T_38e64_row9_col1" class="data row9 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_38e64_row10_col0" class="data row10 col0" >israeli</td>
#       <td id="T_38e64_row10_col1" class="data row10 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_38e64_row11_col0" class="data row11 col0" >turkey</td>
#       <td id="T_38e64_row11_col1" class="data row11 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_38e64_row12_col0" class="data row12 col0" >helicopter</td>
#       <td id="T_38e64_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_38e64_row13_col0" class="data row13 col0" >abc</td>
#       <td id="T_38e64_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_38e64_row14_col0" class="data row14 col0" >typhoondevastated</td>
#       <td id="T_38e64_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_38e64_row15_col0" class="data row15 col0" >saipan</td>
#       <td id="T_38e64_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_38e64_row16_col0" class="data row16 col0" >conclusively</td>
#       <td id="T_38e64_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_38e64_row17_col0" class="data row17 col0" >projected</td>
#       <td id="T_38e64_row17_col1" class="data row17 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_38e64_row18_col0" class="data row18 col0" >bestnaijamade</td>
#       <td id="T_38e64_row18_col1" class="data row18 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_38e64_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_38e64_row19_col0" class="data row19 col0" >signs</td>
#       <td id="T_38e64_row19_col1" class="data row19 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(Unique_true, path=['words'], values='count',title='Tree Of Unique True Words')
fig.show()
# Out:
# <div>                            <div id="2b96cdee-d28e-4de6-88b3-ff292e6b8d62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b96cdee-d28e-4de6-88b3-ff292e6b8d62")) {                    Plotly.newPlot(                        "2b96cdee-d28e-4de6-88b3-ff292e6b8d62",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["abc","bestnaijamade","conclusively","debris","derailment","detonated","helicopter","investigators","israeli","legionnaires","migrants","mosque","northern","pkk","projected","saipan","severe","signs","turkey","typhoondevastated"],"labels":["abc","bestnaijamade","conclusively","debris","derailment","detonated","helicopter","investigators","israeli","legionnaires","migrants","mosque","northern","pkk","projected","saipan","severe","signs","turkey","typhoondevastated"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[25,24,25,50,40,31,25,37,28,62,39,35,64,31,24,25,47,23,28,25],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_true['count'], labels=Unique_true.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique True Words')
plt.show()

# %%
Unique_fake = words_unique(0, 10, raw_text)
print("The top 10 unique words in Negative Tweets are:")
Unique_fake.style.background_gradient(cmap='Reds')
# Out:
# The top 10 unique words in Negative Tweets are:
# <style type="text/css">
# #T_820e8_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_820e8_row1_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_820e8_row2_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_820e8_row3_col1, #T_820e8_row4_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_820e8_row5_col1, #T_820e8_row6_col1, #T_820e8_row7_col1, #T_820e8_row8_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_820e8_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_820e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_820e8_row0_col0" class="data row0 col0" >lmao</td>
#       <td id="T_820e8_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_820e8_row1_col0" class="data row1 col0" >king</td>
#       <td id="T_820e8_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_820e8_row2_col0" class="data row2 col0" >career</td>
#       <td id="T_820e8_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_820e8_row3_col0" class="data row3 col0" >aftershock</td>
#       <td id="T_820e8_row3_col1" class="data row3 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_820e8_row4_col0" class="data row4 col0" >louis</td>
#       <td id="T_820e8_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_820e8_row5_col0" class="data row5 col0" >edm</td>
#       <td id="T_820e8_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_820e8_row6_col0" class="data row6 col0" >lucky</td>
#       <td id="T_820e8_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_820e8_row7_col0" class="data row7 col0" >complete</td>
#       <td id="T_820e8_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_820e8_row8_col0" class="data row8 col0" >arianagrande</td>
#       <td id="T_820e8_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_820e8_row9_col0" class="data row9 col0" >shall</td>
#       <td id="T_820e8_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_fake['count'], labels=Unique_fake.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Fake Words')
plt.show()

# %%
text = " ".join(i for i in temp_positive.Common_words)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
more_stopwords = {'u', "im"}
stopwords = stopwords.union(more_stopwords)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stopwords).generate(text)
# Display the generated image:
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("WordClound of true disaster", fontdict={'size': 40,  'verticalalignment': 'bottom'})
plt.axis("off")
plt.show()

# %%
real_disaster
# Out:
#          id                                               text  target  \
# 15       23                                       whats up man       0
# 16       24                                      i love fruits       0
# 17       25                                   summer is lovely       0
# 18       26                                  my car is so fast       0
# 19       28                             what a goooooooaaaaaal       0
# ...     ...                                                ...     ...
# 7581  10833  engineshed great atmosphere at the british lio...       0
# 7582  10834  cramer igers  words that wrecked disneys stock...       0
# 7584  10837  these boxes are ready to explode exploding kit...       0
# 7587  10841                                  sirens everywhere       0
# 7593  10848  i just heard a really loud bang and everyone i...       0
#
#                                               temp_list
# 15                                         [whats, man]
# 16                                       [love, fruits]
# 17                                     [summer, lovely]
# 18                                          [car, fast]
# 19                                    [goooooooaaaaaal]
# ...                                                 ...
# 7581  [engineshed, great, atmosphere, british, lion,...
# 7582  [cramer, igers, words, wrecked, disneys, stock...
# 7584  [boxes, ready, explode, exploding, kittens, fi...
# 7587                               [sirens, everywhere]
# 7593  [heard, really, loud, bang, everyone, asleep, ...
#
# [4342 rows x 4 columns]

# %%
real_disaster.head()
# Out:
#     id                    text  target          temp_list
# 15  23            whats up man       0       [whats, man]
# 16  24           i love fruits       0     [love, fruits]
# 17  25        summer is lovely       0   [summer, lovely]
# 18  26       my car is so fast       0        [car, fast]
# 19  28  what a goooooooaaaaaal       0  [goooooooaaaaaal]

# %%
text = " ".join(i for i in temp_negative.Common_words)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stopwords).generate(text)
# Display the generated image:
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("WordClound of fake disaster", fontdict={'size': 40,  'verticalalignment': 'bottom'})
plt.axis("off")
plt.show()

# %% [markdown]
# # Prepareration data for create model

# %% [markdown]
# ## Create function Clean word
# Make text lowercase, remove text in square brackets,remove links,remove punctuation and remove words containing numbers.

# %%
from nltk import corpus
import re
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords 


SENTIMENT_CSV = "../input/nlp-getting-started/train.csv"
def remove_stopwords(sentence):
    # List of stopwords
    sentence = sentence.lower()
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    sentence = re.sub('\[.*?\]', '', sentence)
    sentence = re.sub('https?://\S+|www\.\S+', '', sentence)
    sentence = re.sub('<.*?>+', '', sentence)
    sentencet = re.sub('[%s]' % re.escape(string.punctuation), '', sentence)
    sentence = re.sub('\n', '', sentence)
    sentence = re.sub('\w*\d\w*', '', sentence)
    sentence  = sentence.split()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    sentence = [word for word in sentence if not word in set(all_stopwords)]
    snow_stemmer = SnowballStemmer(language='english')
    sentence = [snow_stemmer.stem(word) for word in sentence]
    sentence = " ".join(sentence)
        
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Create function read csv

# %%
def parse_data_from_file(filename):
    
    sentences = []
    labels = []
    
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
        for row in reader:
            
            labels.append(int(row[4]))
            sentence = row[3]
            sentence = remove_stopwords(sentence)
            sentences.append(sentence)

        
    return sentences, labels

# %%
sentences, labels = parse_data_from_file(SENTIMENT_CSV)

print(f"dataset contains {len(sentences)} examples\n")

print(f"Text of second example should look like this:\n{sentences[0]}\n")
print(f"Text of fourth example should look like this:\n{sentences[3]}")

print(f"\nLabels of last 5 examples should look like this:\n{labels[-5:]}")
# Out:
# dataset contains 7613 examples
#
# Text of second example should look like this:
# deed reason earthquak may allah forgiv us
#
# Text of fourth example should look like this:
# peopl receiv wildfir evacu order california
#
# Labels of last 5 examples should look like this:
# [1, 1, 1, 1, 1]

# %% [markdown]
# # Training - Validation Split

# %%
x_train, x_val, y_train, y_val = train_test_split(sentences, labels,  
                                                  random_state=1, 
                                                  test_size=0.2, shuffle=True)

# %%
print(f"There are {len(x_train)} sentences for training.\n")
print(f"There are {len(y_train)} labels for training.\n")
print(f"There are {len(x_val)} sentences for validation.\n")
print(f"There are {len(y_val)} labels for validation.")
# Out:
# There are 6090 sentences for training.
#
# There are 6090 labels for training.
#
# There are 1523 sentences for validation.
#
# There are 1523 labels for validation.

# %%
unique, counts = np.unique(y_train, return_counts=True)
train_result = np.column_stack((unique, counts)) 
print(train_result)
# Out:
# [[   0 3460]
#  [   1 2630]]

# %%
unique, counts = np.unique(y_val, return_counts=True)
val_result = np.column_stack((unique, counts)) 
print(val_result)
# Out:
# [[  0 882]
#  [  1 641]]

# %% [markdown]
# ## Tokenization - Sequences, truncating and padding

# %%
def fit_tokenizer(train_sentences, oov_token):
    
    
    # Instantiate the Tokenizer class, passing in the correct values for num_words and oov_token
    tokenizer = Tokenizer(oov_token = oov_token)
    
    # Fit the tokenizer to the training sentences
    tokenizer.fit_on_texts(train_sentences)
    
    
    return tokenizer

# %%
OOV_TOKEN = "<OOV>"
tokenizer = fit_tokenizer(x_train, OOV_TOKEN)

word_index = tokenizer.word_index
VOCAB_SIZE = len(word_index)

print(f"Vocabulary contains {VOCAB_SIZE} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
print(f"\nindex of word 'dog' should be {word_index['dog']}")
# Out:
# Vocabulary contains 16187 words
#
# <OOV> token included in vocabulary
#
# index of word 'dog' should be 404

# %%
def seq_pad_and_trunc(sentences, tokenizer, padding, truncating, maxlen):

       
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)
    
    # Pad the sequences using the correct padding, truncating and maxlen
    pad_trunc_sequences = pad_sequences(sequences, padding= padding, maxlen = maxlen, truncating = truncating)
    
    
    return pad_trunc_sequences

# %%
EMBEDDING_DIM = 100
MAXLEN = 30
TRUNCATING = 'post'
PADDING = 'post'
train_pad_trunc_seq = seq_pad_and_trunc(x_train, tokenizer, PADDING, TRUNCATING, MAXLEN)
val_pad_trunc_seq = seq_pad_and_trunc(x_val, tokenizer, PADDING, TRUNCATING, MAXLEN)

print(f"Padded and truncated training sequences have shape: {train_pad_trunc_seq.shape}\n")
print(f"Padded and truncated validation sequences have shape: {val_pad_trunc_seq.shape}\n")
# Out:
# Padded and truncated training sequences have shape: (6090, 30)
#
# Padded and truncated validation sequences have shape: (1523, 30)

# %%
train_labels = np.array(y_train)
val_labels = np.array(y_val)

# %% [markdown]
# ## Using pre-defined Embeddings 6b100d

# %%
# Define path to file containing the embeddings
GLOVE_FILE = '../input/glove6b100dtxt/glove.6B.100d.txt'

# Initialize an empty embeddings index dictionary
GLOVE_EMBEDDINGS = {}

# Read file and fill GLOVE_EMBEDDINGS with its contents
with open(GLOVE_FILE) as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        GLOVE_EMBEDDINGS[word] = coefs

# %%
test_word = 'dog'

test_vector = GLOVE_EMBEDDINGS[test_word]

print(f"Vector representation of word {test_word} looks like this:\n\n{test_vector}")
# Out:
# Vector representation of word dog looks like this:
#
# [ 0.30817    0.30938    0.52803   -0.92543   -0.73671    0.63475
#   0.44197    0.10262   -0.09142   -0.56607   -0.5327     0.2013
#   0.7704    -0.13983    0.13727    1.1128     0.89301   -0.17869
#  -0.0019722  0.57289    0.59479    0.50428   -0.28991   -1.3491
#   0.42756    1.2748    -1.1613    -0.41084    0.042804   0.54866
#   0.18897    0.3759     0.58035    0.66975    0.81156    0.93864
#  -0.51005   -0.070079   0.82819   -0.35346    0.21086   -0.24412
#  -0.16554   -0.78358   -0.48482    0.38968   -0.86356   -0.016391
#   0.31984   -0.49246   -0.069363   0.018869  -0.098286   1.3126
#  -0.12116   -1.2399    -0.091429   0.35294    0.64645    0.089642
#   0.70294    1.1244     0.38639    0.52084    0.98787    0.79952
#  -0.34625    0.14095    0.80167    0.20987   -0.86007   -0.15308
#   0.074523   0.40816    0.019208   0.51587   -0.34428   -0.24525
#  -0.77984    0.27425    0.22418    0.20164    0.017431  -0.014697
#  -1.0235    -0.39695   -0.0056188  0.30569    0.31748    0.021404
#   0.11837   -0.11319    0.42456    0.53405   -0.16717   -0.27185
#  -0.6255     0.12883    0.62529   -0.52086  ]

# %%
len(GLOVE_EMBEDDINGS)
# Out:
# 400000

# %%
print(f"Each word vector has shape: {test_vector.shape}")
# Out:
# Each word vector has shape: (100,)

# %%
hits = 0
misses = 0
# Prepare embedding matrix
EMBEDDINGS_MATRIX = np.zeros((VOCAB_SIZE+1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = GLOVE_EMBEDDINGS.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        EMBEDDINGS_MATRIX[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 7603 words (8584 misses)

# %% [markdown]
# ## Create function ROC evaluation

# %%
def roc_auc(predictions,target):
    '''
    This methods returns the AUC Score when given the Predictions
    and Labels
    '''
    
    fpr, tpr, thresholds = metrics.roc_curve(target, predictions)
    roc_auc = metrics.auc(fpr, tpr)
    return roc_auc

# %% [markdown]
# # LSTM

# %%
def LSTM(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    LSTM_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    LSTM_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return LSTM_model

# %%
LSTM_model = LSTM(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
LSTM_model.summary()
# Out:
# 2022-04-09 09:01:17.704833: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 30, 100)           1618800
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                42240
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 1,661,105
# Trainable params: 42,305
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historyLstm = LSTM_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 30, batch_size=64)
# Out:
# 2022-04-09 09:01:18.392257: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 96/96 [==============================] - 6s 38ms/step - loss: 0.5488 - accuracy: 0.7404 - val_loss: 0.5100 - val_accuracy: 0.7603
# Epoch 2/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.4773 - accuracy: 0.7872 - val_loss: 0.4979 - val_accuracy: 0.7814
# Epoch 3/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.4619 - accuracy: 0.7949 - val_loss: 0.4784 - val_accuracy: 0.7905
# Epoch 4/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.4454 - accuracy: 0.8080 - val_loss: 0.4761 - val_accuracy: 0.7938
# Epoch 5/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.4325 - accuracy: 0.8126 - val_loss: 0.4874 - val_accuracy: 0.7820
# Epoch 6/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.4211 - accuracy: 0.8200 - val_loss: 0.4832 - val_accuracy: 0.7768
# Epoch 7/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.4023 - accuracy: 0.8315 - val_loss: 0.4787 - val_accuracy: 0.7794
# Epoch 8/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.3890 - accuracy: 0.8397 - val_loss: 0.5065 - val_accuracy: 0.7905
# Epoch 9/30
# 96/96 [==============================] - 3s 33ms/step - loss: 0.3754 - accuracy: 0.8432 - val_loss: 0.4803 - val_accuracy: 0.8017
# Epoch 10/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.3470 - accuracy: 0.8560 - val_loss: 0.5152 - val_accuracy: 0.7859
# Epoch 11/30
# 96/96 [==============================] - 4s 38ms/step - loss: 0.3352 - accuracy: 0.8654 - val_loss: 0.5058 - val_accuracy: 0.7984
# Epoch 12/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.3083 - accuracy: 0.8826 - val_loss: 0.5389 - val_accuracy: 0.7965
# Epoch 13/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.2978 - accuracy: 0.8883 - val_loss: 0.5208 - val_accuracy: 0.7925
# Epoch 14/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.2740 - accuracy: 0.8949 - val_loss: 0.5287 - val_accuracy: 0.7879
# Epoch 15/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.2719 - accuracy: 0.8952 - val_loss: 0.5963 - val_accuracy: 0.7827
# Epoch 16/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.2543 - accuracy: 0.9046 - val_loss: 0.5728 - val_accuracy: 0.7787
# Epoch 17/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.2436 - accuracy: 0.9107 - val_loss: 0.5624 - val_accuracy: 0.7879
# Epoch 18/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.2254 - accuracy: 0.9189 - val_loss: 0.6595 - val_accuracy: 0.7873
# Epoch 19/30
# 96/96 [==============================] - 3s 34ms/step - loss: 0.2162 - accuracy: 0.9232 - val_loss: 0.6118 - val_accuracy: 0.7754
# Epoch 20/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.2120 - accuracy: 0.9230 - val_loss: 0.5602 - val_accuracy: 0.7859
# Epoch 21/30
# 96/96 [==============================] - 3s 35ms/step - loss: 0.2002 - accuracy: 0.9289 - val_loss: 0.6653 - val_accuracy: 0.7794
# Epoch 22/30
# 96/96 [==============================] - 3s 34ms/step - loss: 0.1786 - accuracy: 0.9394 - val_loss: 0.6952 - val_accuracy: 0.7735
# Epoch 23/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.1910 - accuracy: 0.9319 - val_loss: 0.7074 - val_accuracy: 0.7715
# Epoch 24/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.1577 - accuracy: 0.9494 - val_loss: 0.7322 - val_accuracy: 0.7774
# Epoch 25/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.1482 - accuracy: 0.9537 - val_loss: 0.7681 - val_accuracy: 0.7814
# Epoch 26/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.1382 - accuracy: 0.9567 - val_loss: 0.8249 - val_accuracy: 0.7505
# Epoch 27/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.1458 - accuracy: 0.9540 - val_loss: 0.7300 - val_accuracy: 0.7748
# Epoch 28/30
# 96/96 [==============================] - 3s 31ms/step - loss: 0.1419 - accuracy: 0.9542 - val_loss: 0.7640 - val_accuracy: 0.7827
# Epoch 29/30
# 96/96 [==============================] - 3s 33ms/step - loss: 0.1485 - accuracy: 0.9525 - val_loss: 0.8932 - val_accuracy: 0.7498
# Epoch 30/30
# 96/96 [==============================] - 3s 32ms/step - loss: 0.1228 - accuracy: 0.9622 - val_loss: 0.9173 - val_accuracy: 0.7531

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historyLstm.history['loss']
val_loss = historyLstm.history['val_loss']
epochs = [*range(30)]

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historyLstm.history['accuracy']
val_acc = historyLstm.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = LSTM_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
print("Auc: %.2f%%" % (roc_auc(scores,val_labels)))
# Out:
# Accuracy : 0.7531188443860801
# F1_Score : 0.7181409295352323
# Auc: 0.75%

# %%
scores_model = []
scores_model.append({'Model': 'LSTM','AUC_Score': roc_auc(scores,val_labels),'Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Bidirectional LSTM

# %%
def Bi_LSTM(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    bilstm_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)), 
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    bilstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return bilstm_model

# %%
bilstm_model = Bi_LSTM(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
bilstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 100)           1618800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               84480
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,703,409
# Trainable params: 84,609
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historybilstm = bilstm_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 30, batch_size=64)
# Out:
# Epoch 1/30
# 96/96 [==============================] - 11s 73ms/step - loss: 0.5369 - accuracy: 0.7319 - val_loss: 0.4857 - val_accuracy: 0.7886
# Epoch 2/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.4620 - accuracy: 0.7941 - val_loss: 0.5044 - val_accuracy: 0.7643
# Epoch 3/30
# 96/96 [==============================] - 5s 54ms/step - loss: 0.4444 - accuracy: 0.8010 - val_loss: 0.4805 - val_accuracy: 0.7814
# Epoch 4/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.4246 - accuracy: 0.8133 - val_loss: 0.4744 - val_accuracy: 0.7919
# Epoch 5/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.4069 - accuracy: 0.8228 - val_loss: 0.4795 - val_accuracy: 0.7820
# Epoch 6/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.3902 - accuracy: 0.8291 - val_loss: 0.4871 - val_accuracy: 0.7919
# Epoch 7/30
# 96/96 [==============================] - 6s 61ms/step - loss: 0.3713 - accuracy: 0.8397 - val_loss: 0.4957 - val_accuracy: 0.7899
# Epoch 8/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.3420 - accuracy: 0.8555 - val_loss: 0.5440 - val_accuracy: 0.7715
# Epoch 9/30
# 96/96 [==============================] - 5s 54ms/step - loss: 0.3288 - accuracy: 0.8583 - val_loss: 0.5104 - val_accuracy: 0.7859
# Epoch 10/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.2959 - accuracy: 0.8783 - val_loss: 0.5378 - val_accuracy: 0.7827
# Epoch 11/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.2686 - accuracy: 0.8920 - val_loss: 0.5805 - val_accuracy: 0.7827
# Epoch 12/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.2499 - accuracy: 0.9011 - val_loss: 0.5938 - val_accuracy: 0.7702
# Epoch 13/30
# 96/96 [==============================] - 6s 62ms/step - loss: 0.2211 - accuracy: 0.9122 - val_loss: 0.6792 - val_accuracy: 0.7768
# Epoch 14/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.2002 - accuracy: 0.9200 - val_loss: 0.6626 - val_accuracy: 0.7748
# Epoch 15/30
# 96/96 [==============================] - 5s 54ms/step - loss: 0.1702 - accuracy: 0.9346 - val_loss: 0.7262 - val_accuracy: 0.7708
# Epoch 16/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.1554 - accuracy: 0.9384 - val_loss: 0.7907 - val_accuracy: 0.7617
# Epoch 17/30
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1402 - accuracy: 0.9452 - val_loss: 0.8685 - val_accuracy: 0.7643
# Epoch 18/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.1199 - accuracy: 0.9563 - val_loss: 0.8983 - val_accuracy: 0.7557
# Epoch 19/30
# 96/96 [==============================] - 6s 62ms/step - loss: 0.1076 - accuracy: 0.9616 - val_loss: 0.8819 - val_accuracy: 0.7610
# Epoch 20/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0911 - accuracy: 0.9681 - val_loss: 0.9741 - val_accuracy: 0.7676
# Epoch 21/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.0852 - accuracy: 0.9711 - val_loss: 1.0412 - val_accuracy: 0.7597
# Epoch 22/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0810 - accuracy: 0.9708 - val_loss: 0.9980 - val_accuracy: 0.7636
# Epoch 23/30
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0697 - accuracy: 0.9760 - val_loss: 1.0264 - val_accuracy: 0.7630
# Epoch 24/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0645 - accuracy: 0.9773 - val_loss: 1.1662 - val_accuracy: 0.7630
# Epoch 25/30
# 96/96 [==============================] - 6s 64ms/step - loss: 0.0686 - accuracy: 0.9759 - val_loss: 1.0593 - val_accuracy: 0.7597
# Epoch 26/30
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0716 - accuracy: 0.9755 - val_loss: 1.1462 - val_accuracy: 0.7649
# Epoch 27/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.0619 - accuracy: 0.9783 - val_loss: 1.1500 - val_accuracy: 0.7571
# Epoch 28/30
# 96/96 [==============================] - 5s 55ms/step - loss: 0.0501 - accuracy: 0.9816 - val_loss: 1.1929 - val_accuracy: 0.7518
# Epoch 29/30
# 96/96 [==============================] - 6s 57ms/step - loss: 0.0609 - accuracy: 0.9770 - val_loss: 1.1768 - val_accuracy: 0.7610
# Epoch 30/30
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0503 - accuracy: 0.9813 - val_loss: 1.2544 - val_accuracy: 0.7518

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historybilstm.history['loss']
val_loss = historybilstm.history['val_loss']


#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historybilstm.history['accuracy']
val_acc = historybilstm.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = bilstm_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
print("Auc: %.2f%%" % (roc_auc(scores,val_labels)))
# Out:
# Accuracy : 0.7518056467498359
# F1_Score : 0.704225352112676
# Auc: 0.75%

# %%
scores_model.append({'Model': 'Bi-directional','AUC_Score': roc_auc(scores,val_labels),'Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Bidirectional LSTM + Dropout

# %%
def Bi_LSTM_Drop(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    bilstm_Drop_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True, dropout = 0.5)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, dropout = 0.5)),
        tf.keras.layers.Dropout(0.5),
        #tf.keras.layers.Dense(16, activation = "relu"),
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    bilstm_Drop_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return bilstm_Drop_model

# %%
bilstm_Drop_model = Bi_LSTM_Drop(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
bilstm_Drop_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 30, 100)           1618800
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 100)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 30, 256)           234496
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,017,777
# Trainable params: 398,977
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historybilastm_drop = bilstm_Drop_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 30, batch_size=64)
# Out:
# Epoch 1/30
# 96/96 [==============================] - 27s 187ms/step - loss: 0.5847 - accuracy: 0.7015 - val_loss: 0.5060 - val_accuracy: 0.7689
# Epoch 2/30
# 96/96 [==============================] - 17s 178ms/step - loss: 0.5372 - accuracy: 0.7399 - val_loss: 0.5143 - val_accuracy: 0.7577
# Epoch 3/30
# 96/96 [==============================] - 16s 169ms/step - loss: 0.5260 - accuracy: 0.7506 - val_loss: 0.4899 - val_accuracy: 0.7866
# Epoch 4/30
# 96/96 [==============================] - 16s 171ms/step - loss: 0.5273 - accuracy: 0.7502 - val_loss: 0.4928 - val_accuracy: 0.7859
# Epoch 5/30
# 96/96 [==============================] - 16s 164ms/step - loss: 0.5141 - accuracy: 0.7571 - val_loss: 0.4858 - val_accuracy: 0.7833
# Epoch 6/30
# 96/96 [==============================] - 16s 169ms/step - loss: 0.5148 - accuracy: 0.7557 - val_loss: 0.5211 - val_accuracy: 0.7433
# Epoch 7/30
# 96/96 [==============================] - 17s 170ms/step - loss: 0.5128 - accuracy: 0.7516 - val_loss: 0.4855 - val_accuracy: 0.7827
# Epoch 8/30
# 96/96 [==============================] - 17s 177ms/step - loss: 0.5094 - accuracy: 0.7544 - val_loss: 0.4930 - val_accuracy: 0.7807
# Epoch 9/30
# 96/96 [==============================] - 16s 165ms/step - loss: 0.5061 - accuracy: 0.7686 - val_loss: 0.4824 - val_accuracy: 0.7892
# Epoch 10/30
# 96/96 [==============================] - 16s 167ms/step - loss: 0.4989 - accuracy: 0.7693 - val_loss: 0.4969 - val_accuracy: 0.7728
# Epoch 11/30
# 96/96 [==============================] - 17s 177ms/step - loss: 0.4996 - accuracy: 0.7657 - val_loss: 0.4828 - val_accuracy: 0.7807
# Epoch 12/30
# 96/96 [==============================] - 17s 179ms/step - loss: 0.5037 - accuracy: 0.7652 - val_loss: 0.4745 - val_accuracy: 0.7919
# Epoch 13/30
# 96/96 [==============================] - 16s 166ms/step - loss: 0.4926 - accuracy: 0.7709 - val_loss: 0.4846 - val_accuracy: 0.7748
# Epoch 14/30
# 96/96 [==============================] - 16s 169ms/step - loss: 0.4937 - accuracy: 0.7680 - val_loss: 0.4724 - val_accuracy: 0.7859
# Epoch 15/30
# 96/96 [==============================] - 17s 173ms/step - loss: 0.4867 - accuracy: 0.7704 - val_loss: 0.4818 - val_accuracy: 0.7761
# Epoch 16/30
# 96/96 [==============================] - 17s 182ms/step - loss: 0.4938 - accuracy: 0.7686 - val_loss: 0.4872 - val_accuracy: 0.7761
# Epoch 17/30
# 96/96 [==============================] - 16s 164ms/step - loss: 0.4858 - accuracy: 0.7785 - val_loss: 0.4938 - val_accuracy: 0.7735
# Epoch 18/30
# 96/96 [==============================] - 16s 166ms/step - loss: 0.4807 - accuracy: 0.7760 - val_loss: 0.4799 - val_accuracy: 0.7892
# Epoch 19/30
# 96/96 [==============================] - 17s 173ms/step - loss: 0.4806 - accuracy: 0.7759 - val_loss: 0.4962 - val_accuracy: 0.7781
# Epoch 20/30
# 96/96 [==============================] - 16s 163ms/step - loss: 0.4801 - accuracy: 0.7690 - val_loss: 0.4981 - val_accuracy: 0.7820
# Epoch 21/30
# 96/96 [==============================] - 17s 178ms/step - loss: 0.4755 - accuracy: 0.7800 - val_loss: 0.4956 - val_accuracy: 0.7800
# Epoch 22/30
# 96/96 [==============================] - 16s 163ms/step - loss: 0.4747 - accuracy: 0.7837 - val_loss: 0.5195 - val_accuracy: 0.7630
# Epoch 23/30
# 96/96 [==============================] - 17s 176ms/step - loss: 0.4749 - accuracy: 0.7773 - val_loss: 0.4809 - val_accuracy: 0.7925
# Epoch 24/30
# 96/96 [==============================] - 16s 163ms/step - loss: 0.4700 - accuracy: 0.7790 - val_loss: 0.5238 - val_accuracy: 0.7623
# Epoch 25/30
# 96/96 [==============================] - 17s 176ms/step - loss: 0.4711 - accuracy: 0.7859 - val_loss: 0.4978 - val_accuracy: 0.7676
# Epoch 26/30
# 96/96 [==============================] - 16s 166ms/step - loss: 0.4635 - accuracy: 0.7819 - val_loss: 0.4912 - val_accuracy: 0.7971
# Epoch 27/30
# 96/96 [==============================] - 17s 178ms/step - loss: 0.4580 - accuracy: 0.7890 - val_loss: 0.5023 - val_accuracy: 0.7722
# Epoch 28/30
# 96/96 [==============================] - 16s 163ms/step - loss: 0.4541 - accuracy: 0.7964 - val_loss: 0.4807 - val_accuracy: 0.7814
# Epoch 29/30
# 96/96 [==============================] - 17s 179ms/step - loss: 0.4644 - accuracy: 0.7906 - val_loss: 0.4852 - val_accuracy: 0.7899
# Epoch 30/30
# 96/96 [==============================] - 16s 163ms/step - loss: 0.4581 - accuracy: 0.7944 - val_loss: 0.4896 - val_accuracy: 0.7886

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historybilastm_drop.history['loss']
val_loss = historybilastm_drop.history['val_loss']

epochs = [*range(30)]

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historybilastm_drop.history['accuracy']
val_acc = historybilastm_drop.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = bilstm_Drop_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
print("Auc: %.2f%%" % (roc_auc(scores,val_labels)))
# Out:
# Accuracy : 0.788575180564675
# F1_Score : 0.7364975450081832
# Auc: 0.78%

# %%
scores_model.append({'Model': 'Bi-directional_Dropout','AUC_Score': roc_auc(scores,val_labels),'Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Result table

# %%
# Visualization of Results obtained from various Deep learning models
results = pd.DataFrame(scores_model).sort_values(by='AUC_Score',ascending=False)
results.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_1892c_row0_col1, #T_1892c_row0_col2, #T_1892c_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1892c_row1_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_1892c_row1_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_1892c_row1_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_1892c_row2_col1, #T_1892c_row2_col2, #T_1892c_row2_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_1892c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >AUC_Score</th>
#       <th class="col_heading level0 col2" >Accuracy_Score</th>
#       <th class="col_heading level0 col3" >F1_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1892c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_1892c_row0_col0" class="data row0 col0" >Bi-directional_Dropout</td>
#       <td id="T_1892c_row0_col1" class="data row0 col1" >0.776751</td>
#       <td id="T_1892c_row0_col2" class="data row0 col2" >0.788575</td>
#       <td id="T_1892c_row0_col3" class="data row0 col3" >0.736498</td>
#     </tr>
#     <tr>
#       <th id="T_1892c_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_1892c_row1_col0" class="data row1 col0" >LSTM</td>
#       <td id="T_1892c_row1_col1" class="data row1 col1" >0.752320</td>
#       <td id="T_1892c_row1_col2" class="data row1 col2" >0.753119</td>
#       <td id="T_1892c_row1_col3" class="data row1 col3" >0.718141</td>
#     </tr>
#     <tr>
#       <th id="T_1892c_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_1892c_row2_col0" class="data row2 col0" >Bi-directional</td>
#       <td id="T_1892c_row2_col1" class="data row2 col1" >0.745005</td>
#       <td id="T_1892c_row2_col2" class="data row2 col2" >0.751806</td>
#       <td id="T_1892c_row2_col3" class="data row2 col3" >0.704225</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Edit by Sira Haruethaipree
