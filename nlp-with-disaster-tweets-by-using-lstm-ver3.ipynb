# %% [markdown]
# <a href="https://www.kaggle.com/code/guisira/nlp-with-disaster-tweets-by-using-lstm?scriptVersionId=105146523" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/glove6b100dtxt/glove.6B.100d.txt
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %% [markdown]
# ## Import library

# %%
import csv
import string 
import random
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from scipy.stats import linregress
from nltk import corpus
import re
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.stem.snowball import SnowballStemmer
import seaborn as sns
from collections import Counter
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Sentiment Extaction-Analysis EDA

# %%
df_train = pd.read_csv("/kaggle/input/nlp-getting-started/train.csv")

# %%
print(df_train.shape)
# Out:
# (7613, 5)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
df_train = df_train[["id","text","target"]]

# %%
df_train.head()
# Out:
#    id                                               text  target
# 0   1  Our Deeds are the Reason of this #earthquake M...       1
# 1   4             Forest fire near La Ronge Sask. Canada       1
# 2   5  All residents asked to 'shelter in place' are ...       1
# 3   6  13,000 people receive #wildfires evacuation or...       1
# 4   7  Just got sent this photo from Ruby #Alaska as ...       1

# %%
temp = df_train.groupby('target').count()['text'].reset_index().sort_values(by='text',ascending=False)
temp
# Out:
#    target  text
# 0       0  4342
# 1       1  3271

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='target',data=df_train)
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
def clean_text(text) :
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
df_train['text'] = df_train['text'].apply(lambda x:clean_text(x))

# %%
df_train['temp_list'] = df_train['text'].apply(lambda x:str(x).split())
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(10))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_a876a_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a876a_row1_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_a876a_row2_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_a876a_row3_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_a876a_row4_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_a876a_row5_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_a876a_row6_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_a876a_row7_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_a876a_row8_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_a876a_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_a876a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a876a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a876a_row0_col0" class="data row0 col0" >the</td>
#       <td id="T_a876a_row0_col1" class="data row0 col1" >3248</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a876a_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_a876a_row1_col1" class="data row1 col1" >2167</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a876a_row2_col0" class="data row2 col0" >in</td>
#       <td id="T_a876a_row2_col1" class="data row2 col1" >1971</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a876a_row3_col0" class="data row3 col0" >to</td>
#       <td id="T_a876a_row3_col1" class="data row3 col1" >1943</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a876a_row4_col0" class="data row4 col0" >of</td>
#       <td id="T_a876a_row4_col1" class="data row4 col1" >1821</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a876a_row5_col0" class="data row5 col0" >and</td>
#       <td id="T_a876a_row5_col1" class="data row5 col1" >1410</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a876a_row6_col0" class="data row6 col0" >i</td>
#       <td id="T_a876a_row6_col1" class="data row6 col1" >1363</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a876a_row7_col0" class="data row7 col0" >is</td>
#       <td id="T_a876a_row7_col1" class="data row7 col1" >942</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a876a_row8_col0" class="data row8 col0" >for</td>
#       <td id="T_a876a_row8_col1" class="data row8 col1" >889</td>
#     </tr>
#     <tr>
#       <th id="T_a876a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a876a_row9_col0" class="data row9 col0" >on</td>
#       <td id="T_a876a_row9_col1" class="data row9 col1" >850</td>
#     </tr>
#   </tbody>
# </table>

# %%
def remove_stopword(x):
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    return [word for word in x if not word in set(all_stopwords)]

df_train['temp_list'] = df_train['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df_train['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_8788f_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_8788f_row1_col1 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_8788f_row2_col1 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_8788f_row3_col1 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_8788f_row4_col1 {
#   background-color: #8683bd;
#   color: #f1f1f1;
# }
# #T_8788f_row5_col1 {
#   background-color: #8e8ac0;
#   color: #f1f1f1;
# }
# #T_8788f_row6_col1 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_8788f_row7_col1 {
#   background-color: #b3b3d6;
#   color: #000000;
# }
# #T_8788f_row8_col1 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_8788f_row9_col1 {
#   background-color: #bdbedc;
#   color: #000000;
# }
# #T_8788f_row10_col1 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_8788f_row11_col1 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_8788f_row12_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_8788f_row13_col1 {
#   background-color: #e5e4f0;
#   color: #000000;
# }
# #T_8788f_row14_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_8788f_row15_col1 {
#   background-color: #f4f3f8;
#   color: #000000;
# }
# #T_8788f_row16_col1 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_8788f_row17_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_8788f_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_8788f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8788f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8788f_row0_col0" class="data row0 col0" >amp</td>
#       <td id="T_8788f_row0_col1" class="data row0 col1" >298</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8788f_row1_col0" class="data row1 col0" >im</td>
#       <td id="T_8788f_row1_col1" class="data row1 col1" >294</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8788f_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_8788f_row2_col1" class="data row2 col1" >293</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8788f_row3_col0" class="data row3 col0" >fire</td>
#       <td id="T_8788f_row3_col1" class="data row3 col1" >248</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8788f_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_8788f_row4_col1" class="data row4 col1" >228</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8788f_row5_col0" class="data row5 col0" >new</td>
#       <td id="T_8788f_row5_col1" class="data row5 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8788f_row6_col0" class="data row6 col0" >via</td>
#       <td id="T_8788f_row6_col1" class="data row6 col1" >220</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_8788f_row7_col0" class="data row7 col0" >people</td>
#       <td id="T_8788f_row7_col1" class="data row7 col1" >196</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_8788f_row8_col0" class="data row8 col0" >one</td>
#       <td id="T_8788f_row8_col1" class="data row8 col1" >191</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_8788f_row9_col0" class="data row9 col0" >dont</td>
#       <td id="T_8788f_row9_col1" class="data row9 col1" >189</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_8788f_row10_col0" class="data row10 col0" >news</td>
#       <td id="T_8788f_row10_col1" class="data row10 col1" >185</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_8788f_row11_col0" class="data row11 col0" >us</td>
#       <td id="T_8788f_row11_col1" class="data row11 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_8788f_row12_col0" class="data row12 col0" >video</td>
#       <td id="T_8788f_row12_col1" class="data row12 col1" >158</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_8788f_row13_col0" class="data row13 col0" >emergency</td>
#       <td id="T_8788f_row13_col1" class="data row13 col1" >156</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_8788f_row14_col0" class="data row14 col0" >disaster</td>
#       <td id="T_8788f_row14_col1" class="data row14 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_8788f_row15_col0" class="data row15 col0" >police</td>
#       <td id="T_8788f_row15_col1" class="data row15 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_8788f_row16_col0" class="data row16 col0" >would</td>
#       <td id="T_8788f_row16_col1" class="data row16 col1" >129</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_8788f_row17_col0" class="data row17 col0" >still</td>
#       <td id="T_8788f_row17_col1" class="data row17 col1" >128</td>
#     </tr>
#     <tr>
#       <th id="T_8788f_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_8788f_row18_col0" class="data row18 col0" >body</td>
#       <td id="T_8788f_row18_col1" class="data row18 col1" >124</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7ab563ac-30cb-4ccb-8b7c-d61a07e96114" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ab563ac-30cb-4ccb-8b7c-d61a07e96114")) {                    Plotly.newPlot(                        "7ab563ac-30cb-4ccb-8b7c-d61a07e96114",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["amp","body","disaster","dont","emergency","fire","get","im","new","news","not","one","people","police","still","us","via","video","would"],"labels":["amp","body","disaster","dont","emergency","fire","get","im","new","news","not","one","people","police","still","us","via","video","would"],"name":"","parents":["","","","","","","","","","","","","","","","","","",""],"values":[298,124,150,189,156,248,228,294,223,185,293,191,196,137,128,162,220,158,129],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlin ...

# %%
real_disaster = df_train[df_train['target']== 0]
fake_disaster = df_train[df_train['target']== 1]

# %%
top = Counter([item for sublist in real_disaster['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive = temp_positive.iloc[0:,:]
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_eb786_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_eb786_row1_col1 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_eb786_row2_col1 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_eb786_row3_col1 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_eb786_row4_col1 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_eb786_row5_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_eb786_row6_col1 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_eb786_row7_col1 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_eb786_row8_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_eb786_row9_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_eb786_row10_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_eb786_row11_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_eb786_row12_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_eb786_row13_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_eb786_row14_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_eb786_row15_col1, #T_eb786_row16_col1, #T_eb786_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_eb786_row18_col1, #T_eb786_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_eb786_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb786_row0_col0" class="data row0 col0" >like</td>
#       <td id="T_eb786_row0_col1" class="data row0 col1" >252</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb786_row1_col0" class="data row1 col0" >im</td>
#       <td id="T_eb786_row1_col1" class="data row1 col1" >239</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb786_row2_col0" class="data row2 col0" >not</td>
#       <td id="T_eb786_row2_col1" class="data row2 col1" >201</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb786_row3_col0" class="data row3 col0" >amp</td>
#       <td id="T_eb786_row3_col1" class="data row3 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb786_row4_col0" class="data row4 col0" >new</td>
#       <td id="T_eb786_row4_col1" class="data row4 col1" >168</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb786_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_eb786_row5_col1" class="data row5 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb786_row6_col0" class="data row6 col0" >dont</td>
#       <td id="T_eb786_row6_col1" class="data row6 col1" >139</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb786_row7_col0" class="data row7 col0" >one</td>
#       <td id="T_eb786_row7_col1" class="data row7 col1" >126</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb786_row8_col0" class="data row8 col0" >body</td>
#       <td id="T_eb786_row8_col1" class="data row8 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb786_row9_col0" class="data row9 col0" >via</td>
#       <td id="T_eb786_row9_col1" class="data row9 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eb786_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_eb786_row10_col1" class="data row10 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eb786_row11_col0" class="data row11 col0" >people</td>
#       <td id="T_eb786_row11_col1" class="data row11 col1" >91</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eb786_row12_col0" class="data row12 col0" >video</td>
#       <td id="T_eb786_row12_col1" class="data row12 col1" >90</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eb786_row13_col0" class="data row13 col0" >love</td>
#       <td id="T_eb786_row13_col1" class="data row13 col1" >88</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eb786_row14_col0" class="data row14 col0" >back</td>
#       <td id="T_eb786_row14_col1" class="data row14 col1" >84</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_eb786_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_eb786_row15_col1" class="data row15 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eb786_row16_col0" class="data row16 col0" >know</td>
#       <td id="T_eb786_row16_col1" class="data row16 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_eb786_row17_col0" class="data row17 col0" >got</td>
#       <td id="T_eb786_row17_col1" class="data row17 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_eb786_row18_col0" class="data row18 col0" >cant</td>
#       <td id="T_eb786_row18_col1" class="data row18 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_eb786_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_eb786_row19_col0" class="data row19 col0" >us</td>
#       <td id="T_eb786_row19_col1" class="data row19 col1" >81</td>
#     </tr>
#   </tbody>
# </table>

# %%
top = Counter([item for sublist in fake_disaster['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_ce8f9_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ce8f9_row1_col1 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_ce8f9_row2_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_ce8f9_row3_col1 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_ce8f9_row4_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_ce8f9_row5_col1 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_ce8f9_row6_col1, #T_ce8f9_row7_col1 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_ce8f9_row8_col1 {
#   background-color: #fca689;
#   color: #000000;
# }
# #T_ce8f9_row9_col1, #T_ce8f9_row10_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_ce8f9_row11_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_ce8f9_row12_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_ce8f9_row13_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_ce8f9_row14_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_ce8f9_row15_col1, #T_ce8f9_row16_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_ce8f9_row17_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_ce8f9_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_ce8f9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce8f9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ce8f9_row0_col0" class="data row0 col0" >news</td>
#       <td id="T_ce8f9_row0_col1" class="data row0 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ce8f9_row1_col0" class="data row1 col0" >via</td>
#       <td id="T_ce8f9_row1_col1" class="data row1 col1" >121</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ce8f9_row2_col0" class="data row2 col0" >disaster</td>
#       <td id="T_ce8f9_row2_col1" class="data row2 col1" >116</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ce8f9_row3_col0" class="data row3 col0" >california</td>
#       <td id="T_ce8f9_row3_col1" class="data row3 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ce8f9_row4_col0" class="data row4 col0" >suicide</td>
#       <td id="T_ce8f9_row4_col1" class="data row4 col1" >110</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ce8f9_row5_col0" class="data row5 col0" >amp</td>
#       <td id="T_ce8f9_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ce8f9_row6_col0" class="data row6 col0" >people</td>
#       <td id="T_ce8f9_row6_col1" class="data row6 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ce8f9_row7_col0" class="data row7 col0" >police</td>
#       <td id="T_ce8f9_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_ce8f9_row8_col0" class="data row8 col0" >killed</td>
#       <td id="T_ce8f9_row8_col1" class="data row8 col1" >93</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_ce8f9_row9_col0" class="data row9 col0" >not</td>
#       <td id="T_ce8f9_row9_col1" class="data row9 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_ce8f9_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_ce8f9_row10_col1" class="data row10 col1" >92</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_ce8f9_row11_col0" class="data row11 col0" >hiroshima</td>
#       <td id="T_ce8f9_row11_col1" class="data row11 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_ce8f9_row12_col0" class="data row12 col0" >fires</td>
#       <td id="T_ce8f9_row12_col1" class="data row12 col1" >84</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_ce8f9_row13_col0" class="data row13 col0" >storm</td>
#       <td id="T_ce8f9_row13_col1" class="data row13 col1" >83</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_ce8f9_row14_col0" class="data row14 col0" >crash</td>
#       <td id="T_ce8f9_row14_col1" class="data row14 col1" >82</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_ce8f9_row15_col0" class="data row15 col0" >us</td>
#       <td id="T_ce8f9_row15_col1" class="data row15 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_ce8f9_row16_col0" class="data row16 col0" >families</td>
#       <td id="T_ce8f9_row16_col1" class="data row16 col1" >81</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_ce8f9_row17_col0" class="data row17 col0" >train</td>
#       <td id="T_ce8f9_row17_col1" class="data row17 col1" >79</td>
#     </tr>
#     <tr>
#       <th id="T_ce8f9_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_ce8f9_row18_col0" class="data row18 col0" >emergency</td>
#       <td id="T_ce8f9_row18_col1" class="data row18 col1" >75</td>
#     </tr>
#   </tbody>
# </table>

# %%
raw_text = [word for word_list in df_train['temp_list'] for word in word_list]

# %%
def words_unique(target,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in df_train[df_train.target != target]['temp_list']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in df_train[df_train.target == target]['temp_list']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %%
Unique_true= words_unique(1, 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_true.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style type="text/css">
# #T_26a93_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_26a93_row1_col1 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_26a93_row2_col1 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_26a93_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_26a93_row4_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_26a93_row5_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_26a93_row6_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_26a93_row7_col1 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_26a93_row8_col1, #T_26a93_row9_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_26a93_row10_col1, #T_26a93_row11_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_26a93_row12_col1, #T_26a93_row13_col1, #T_26a93_row14_col1, #T_26a93_row15_col1, #T_26a93_row16_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_26a93_row17_col1, #T_26a93_row18_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_26a93_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_26a93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26a93_row0_col0" class="data row0 col0" >northern</td>
#       <td id="T_26a93_row0_col1" class="data row0 col1" >64</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26a93_row1_col0" class="data row1 col0" >legionnaires</td>
#       <td id="T_26a93_row1_col1" class="data row1 col1" >62</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26a93_row2_col0" class="data row2 col0" >debris</td>
#       <td id="T_26a93_row2_col1" class="data row2 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26a93_row3_col0" class="data row3 col0" >severe</td>
#       <td id="T_26a93_row3_col1" class="data row3 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26a93_row4_col0" class="data row4 col0" >derailment</td>
#       <td id="T_26a93_row4_col1" class="data row4 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26a93_row5_col0" class="data row5 col0" >migrants</td>
#       <td id="T_26a93_row5_col1" class="data row5 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26a93_row6_col0" class="data row6 col0" >investigators</td>
#       <td id="T_26a93_row6_col1" class="data row6 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26a93_row7_col0" class="data row7 col0" >mosque</td>
#       <td id="T_26a93_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_26a93_row8_col0" class="data row8 col0" >pkk</td>
#       <td id="T_26a93_row8_col1" class="data row8 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_26a93_row9_col0" class="data row9 col0" >detonated</td>
#       <td id="T_26a93_row9_col1" class="data row9 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_26a93_row10_col0" class="data row10 col0" >israeli</td>
#       <td id="T_26a93_row10_col1" class="data row10 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_26a93_row11_col0" class="data row11 col0" >turkey</td>
#       <td id="T_26a93_row11_col1" class="data row11 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_26a93_row12_col0" class="data row12 col0" >helicopter</td>
#       <td id="T_26a93_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_26a93_row13_col0" class="data row13 col0" >abc</td>
#       <td id="T_26a93_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_26a93_row14_col0" class="data row14 col0" >typhoondevastated</td>
#       <td id="T_26a93_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_26a93_row15_col0" class="data row15 col0" >saipan</td>
#       <td id="T_26a93_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_26a93_row16_col0" class="data row16 col0" >conclusively</td>
#       <td id="T_26a93_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_26a93_row17_col0" class="data row17 col0" >projected</td>
#       <td id="T_26a93_row17_col1" class="data row17 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_26a93_row18_col0" class="data row18 col0" >bestnaijamade</td>
#       <td id="T_26a93_row18_col1" class="data row18 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_26a93_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_26a93_row19_col0" class="data row19 col0" >signs</td>
#       <td id="T_26a93_row19_col1" class="data row19 col1" >23</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(Unique_true, path=['words'], values='count',title='Tree Of Unique True Words')
fig.show()
# Out:
# <div>                            <div id="b56ee451-93bf-4e92-965b-e40f22310b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b56ee451-93bf-4e92-965b-e40f22310b10")) {                    Plotly.newPlot(                        "b56ee451-93bf-4e92-965b-e40f22310b10",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["abc","bestnaijamade","conclusively","debris","derailment","detonated","helicopter","investigators","israeli","legionnaires","migrants","mosque","northern","pkk","projected","saipan","severe","signs","turkey","typhoondevastated"],"labels":["abc","bestnaijamade","conclusively","debris","derailment","detonated","helicopter","investigators","israeli","legionnaires","migrants","mosque","northern","pkk","projected","saipan","severe","signs","turkey","typhoondevastated"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[25,24,25,50,40,31,25,37,28,62,39,35,64,31,24,25,47,23,28,25],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_true['count'], labels=Unique_true.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique True Words')
plt.show()

# %%
Unique_fake = words_unique(0, 10, raw_text)
print("The top 10 unique words in Negative Tweets are:")
Unique_fake.style.background_gradient(cmap='Reds')
# Out:
# The top 10 unique words in Negative Tweets are:
# <style type="text/css">
# #T_dd520_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_dd520_row1_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_dd520_row2_col1 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_dd520_row3_col1, #T_dd520_row4_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_dd520_row5_col1, #T_dd520_row6_col1, #T_dd520_row7_col1, #T_dd520_row8_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_dd520_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_dd520_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd520_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd520_row0_col0" class="data row0 col0" >lmao</td>
#       <td id="T_dd520_row0_col1" class="data row0 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd520_row1_col0" class="data row1 col0" >king</td>
#       <td id="T_dd520_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd520_row2_col0" class="data row2 col0" >career</td>
#       <td id="T_dd520_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd520_row3_col0" class="data row3 col0" >aftershock</td>
#       <td id="T_dd520_row3_col1" class="data row3 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd520_row4_col0" class="data row4 col0" >louis</td>
#       <td id="T_dd520_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd520_row5_col0" class="data row5 col0" >edm</td>
#       <td id="T_dd520_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd520_row6_col0" class="data row6 col0" >lucky</td>
#       <td id="T_dd520_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd520_row7_col0" class="data row7 col0" >complete</td>
#       <td id="T_dd520_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd520_row8_col0" class="data row8 col0" >arianagrande</td>
#       <td id="T_dd520_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_dd520_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd520_row9_col0" class="data row9 col0" >shall</td>
#       <td id="T_dd520_row9_col1" class="data row9 col1" >10</td>
#     </tr>
#   </tbody>
# </table>

# %%
from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_fake['count'], labels=Unique_fake.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Fake Words')
plt.show()

# %%
text = " ".join(i for i in temp_positive.Common_words)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
more_stopwords = {'u', "im"}
stopwords = stopwords.union(more_stopwords)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stopwords).generate(text)
# Display the generated image:
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("WordClound of true disaster", fontdict={'size': 40,  'verticalalignment': 'bottom'})
plt.axis("off")
plt.show()

# %%
real_disaster
# Out:
#          id                                               text  target  \
# 15       23                                       whats up man       0
# 16       24                                      i love fruits       0
# 17       25                                   summer is lovely       0
# 18       26                                  my car is so fast       0
# 19       28                             what a goooooooaaaaaal       0
# ...     ...                                                ...     ...
# 7581  10833  engineshed great atmosphere at the british lio...       0
# 7582  10834  cramer igers  words that wrecked disneys stock...       0
# 7584  10837  these boxes are ready to explode exploding kit...       0
# 7587  10841                                  sirens everywhere       0
# 7593  10848  i just heard a really loud bang and everyone i...       0
#
#                                               temp_list
# 15                                         [whats, man]
# 16                                       [love, fruits]
# 17                                     [summer, lovely]
# 18                                          [car, fast]
# 19                                    [goooooooaaaaaal]
# ...                                                 ...
# 7581  [engineshed, great, atmosphere, british, lion,...
# 7582  [cramer, igers, words, wrecked, disneys, stock...
# 7584  [boxes, ready, explode, exploding, kittens, fi...
# 7587                               [sirens, everywhere]
# 7593  [heard, really, loud, bang, everyone, asleep, ...
#
# [4342 rows x 4 columns]

# %%
real_disaster.head()
# Out:
#     id                    text  target          temp_list
# 15  23            whats up man       0       [whats, man]
# 16  24           i love fruits       0     [love, fruits]
# 17  25        summer is lovely       0   [summer, lovely]
# 18  26       my car is so fast       0        [car, fast]
# 19  28  what a goooooooaaaaaal       0  [goooooooaaaaaal]

# %%
text = " ".join(i for i in temp_negative.Common_words)

# Create and generate a word cloud image:
stopwords = set(STOPWORDS)
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords = stopwords).generate(text)
# Display the generated image:
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("WordClound of fake disaster", fontdict={'size': 40,  'verticalalignment': 'bottom'})
plt.axis("off")
plt.show()

# %% [markdown]
# # Prepareration data for create model

# %% [markdown]
# ## Create function Clean word
# Make text lowercase, remove text in square brackets,remove links,remove punctuation and remove words containing numbers.

# %%
from nltk import corpus
import re
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords 


SENTIMENT_CSV = "../input/nlp-getting-started/train.csv"
def remove_stopwords(sentence):
    # List of stopwords
    sentence = sentence.lower()
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    sentence = re.sub('\[.*?\]', '', sentence)
    sentence = re.sub('https?://\S+|www\.\S+', '', sentence)
    sentence = re.sub('<.*?>+', '', sentence)
    sentencet = re.sub('[%s]' % re.escape(string.punctuation), '', sentence)
    sentence = re.sub('\n', '', sentence)
    sentence = re.sub('\w*\d\w*', '', sentence)
    sentence  = sentence.split()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    sentence = [word for word in sentence if not word in set(all_stopwords)]
    snow_stemmer = SnowballStemmer(language='english')
    sentence = [snow_stemmer.stem(word) for word in sentence]
    sentence = " ".join(sentence)
        
    return sentence
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Create function read csv

# %%
def parse_data_from_file(filename):
    
    sentences = []
    labels = []
    
    with open(filename, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
        for row in reader:
            
            labels.append(int(row[4]))
            sentence = row[3]
            sentence = remove_stopwords(sentence)
            sentences.append(sentence)

        
    return sentences, labels

# %%
sentences, labels = parse_data_from_file(SENTIMENT_CSV)

print(f"dataset contains {len(sentences)} examples\n")

print(f"Text of second example should look like this:\n{sentences[0]}\n")
print(f"Text of fourth example should look like this:\n{sentences[3]}")

print(f"\nLabels of last 5 examples should look like this:\n{labels[-5:]}")
# Out:
# dataset contains 7613 examples
#
# Text of second example should look like this:
# deed reason earthquak may allah forgiv us
#
# Text of fourth example should look like this:
# peopl receiv wildfir evacu order california
#
# Labels of last 5 examples should look like this:
# [1, 1, 1, 1, 1]

# %% [markdown]
# # Training - Validation Split

# %%
x_train, x_val, y_train, y_val = train_test_split(sentences, labels,  
                                                  random_state=1, 
                                                  test_size=0.2, shuffle=True)

# %%
print(f"There are {len(x_train)} sentences for training.\n")
print(f"There are {len(y_train)} labels for training.\n")
print(f"There are {len(x_val)} sentences for validation.\n")
print(f"There are {len(y_val)} labels for validation.")
# Out:
# There are 6090 sentences for training.
#
# There are 6090 labels for training.
#
# There are 1523 sentences for validation.
#
# There are 1523 labels for validation.

# %%
unique, counts = np.unique(y_train, return_counts=True)
train_result = np.column_stack((unique, counts)) 
print(train_result)
# Out:
# [[   0 3460]
#  [   1 2630]]

# %%
unique, counts = np.unique(y_val, return_counts=True)
val_result = np.column_stack((unique, counts)) 
print(val_result)
# Out:
# [[  0 882]
#  [  1 641]]

# %% [markdown]
# ## Tokenization - Sequences, truncating and padding

# %%
def fit_tokenizer(train_sentences, oov_token):
    
    
    # Instantiate the Tokenizer class, passing in the correct values for num_words and oov_token
    tokenizer = Tokenizer(oov_token = oov_token)
    
    # Fit the tokenizer to the training sentences
    tokenizer.fit_on_texts(train_sentences)
    
    
    return tokenizer

# %%
OOV_TOKEN = "<OOV>"
tokenizer = fit_tokenizer(x_train, OOV_TOKEN)

word_index = tokenizer.word_index
VOCAB_SIZE = len(word_index)

print(f"Vocabulary contains {VOCAB_SIZE} words\n")
print("<OOV> token included in vocabulary" if "<OOV>" in word_index else "<OOV> token NOT included in vocabulary")
print(f"\nindex of word 'dog' should be {word_index['dog']}")
# Out:
# Vocabulary contains 16187 words
#
# <OOV> token included in vocabulary
#
# index of word 'dog' should be 404

# %%
def seq_pad_and_trunc(sentences, tokenizer, padding, truncating, maxlen):

       
    # Convert sentences to sequences
    sequences = tokenizer.texts_to_sequences(sentences)
    
    # Pad the sequences using the correct padding, truncating and maxlen
    pad_trunc_sequences = pad_sequences(sequences, padding= padding, maxlen = maxlen, truncating = truncating)
    
    
    return pad_trunc_sequences

# %%
EMBEDDING_DIM = 100
MAXLEN = 30
TRUNCATING = 'post'
PADDING = 'post'
train_pad_trunc_seq = seq_pad_and_trunc(x_train, tokenizer, PADDING, TRUNCATING, MAXLEN)
val_pad_trunc_seq = seq_pad_and_trunc(x_val, tokenizer, PADDING, TRUNCATING, MAXLEN)

print(f"Padded and truncated training sequences have shape: {train_pad_trunc_seq.shape}\n")
print(f"Padded and truncated validation sequences have shape: {val_pad_trunc_seq.shape}\n")
# Out:
# Padded and truncated training sequences have shape: (6090, 30)
#
# Padded and truncated validation sequences have shape: (1523, 30)

# %%
train_labels = np.array(y_train)
val_labels = np.array(y_val)

# %% [markdown]
# ## Using pre-defined Embeddings 6b100d

# %%
# Define path to file containing the embeddings
GLOVE_FILE = '../input/glove6b100dtxt/glove.6B.100d.txt'

# Initialize an empty embeddings index dictionary
GLOVE_EMBEDDINGS = {}

# Read file and fill GLOVE_EMBEDDINGS with its contents
with open(GLOVE_FILE) as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        GLOVE_EMBEDDINGS[word] = coefs

# %%
test_word = 'dog'

test_vector = GLOVE_EMBEDDINGS[test_word]

print(f"Vector representation of word {test_word} looks like this:\n\n{test_vector}")
# Out:
# Vector representation of word dog looks like this:
#
# [ 0.30817    0.30938    0.52803   -0.92543   -0.73671    0.63475
#   0.44197    0.10262   -0.09142   -0.56607   -0.5327     0.2013
#   0.7704    -0.13983    0.13727    1.1128     0.89301   -0.17869
#  -0.0019722  0.57289    0.59479    0.50428   -0.28991   -1.3491
#   0.42756    1.2748    -1.1613    -0.41084    0.042804   0.54866
#   0.18897    0.3759     0.58035    0.66975    0.81156    0.93864
#  -0.51005   -0.070079   0.82819   -0.35346    0.21086   -0.24412
#  -0.16554   -0.78358   -0.48482    0.38968   -0.86356   -0.016391
#   0.31984   -0.49246   -0.069363   0.018869  -0.098286   1.3126
#  -0.12116   -1.2399    -0.091429   0.35294    0.64645    0.089642
#   0.70294    1.1244     0.38639    0.52084    0.98787    0.79952
#  -0.34625    0.14095    0.80167    0.20987   -0.86007   -0.15308
#   0.074523   0.40816    0.019208   0.51587   -0.34428   -0.24525
#  -0.77984    0.27425    0.22418    0.20164    0.017431  -0.014697
#  -1.0235    -0.39695   -0.0056188  0.30569    0.31748    0.021404
#   0.11837   -0.11319    0.42456    0.53405   -0.16717   -0.27185
#  -0.6255     0.12883    0.62529   -0.52086  ]

# %%
len(GLOVE_EMBEDDINGS)
# Out:
# 400000

# %%
print(f"Each word vector has shape: {test_vector.shape}")
# Out:
# Each word vector has shape: (100,)

# %%
hits = 0
misses = 0
# Prepare embedding matrix
EMBEDDINGS_MATRIX = np.zeros((VOCAB_SIZE+1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = GLOVE_EMBEDDINGS.get(word)
    if embedding_vector is not None:
        # Words not found in embedding index will be all-zeros.
        # This includes the representation for "padding" and "OOV"
        EMBEDDINGS_MATRIX[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 7603 words (8584 misses)

# %%
def seedTF(seed=21):
    tf.random.set_seed(seed)
seedTF()

# %% [markdown]
# # LSTM

# %%
def LSTM(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    LSTM_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.LSTM(64,return_sequences=True),
        tf.keras.layers.LSTM(32),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    LSTM_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return LSTM_model

# %%
LSTM_model = LSTM(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
LSTM_model.summary()
# Out:
# 2022-09-07 16:24:41.672697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:41.682116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:41.686115: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:41.691871: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-07 16:24:41.693267: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:41.697354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:41.701400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:44.843698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:44.847903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:44.851798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-07 16:24:44.855480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15417 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 30, 100)           1618800
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 64)            42240
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,674,545
# Trainable params: 55,745
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historyLstm = LSTM_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 10, batch_size=64)
# Out:
# 2022-09-07 16:24:46.296859: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 2022-09-07 16:24:50.748660: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 96/96 [==============================] - 8s 17ms/step - loss: 0.5666 - accuracy: 0.7140 - val_loss: 0.5172 - val_accuracy: 0.7768
# Epoch 2/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4889 - accuracy: 0.7787 - val_loss: 0.5004 - val_accuracy: 0.7840
# Epoch 3/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4742 - accuracy: 0.7916 - val_loss: 0.4868 - val_accuracy: 0.7728
# Epoch 4/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4527 - accuracy: 0.8051 - val_loss: 0.4785 - val_accuracy: 0.7873
# Epoch 5/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4420 - accuracy: 0.8108 - val_loss: 0.4880 - val_accuracy: 0.7866
# Epoch 6/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4319 - accuracy: 0.8164 - val_loss: 0.4859 - val_accuracy: 0.7833
# Epoch 7/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.4084 - accuracy: 0.8310 - val_loss: 0.4743 - val_accuracy: 0.7919
# Epoch 8/10
# 96/96 [==============================] - 1s 9ms/step - loss: 0.3957 - accuracy: 0.8335 - val_loss: 0.4946 - val_accuracy: 0.7892
# Epoch 9/10
# 96/96 [==============================] - 1s 10ms/step - loss: 0.3688 - accuracy: 0.8499 - val_loss: 0.5134 - val_accuracy: 0.7840
# Epoch 10/10
# 96/96 [==============================] - 1s 11ms/step - loss: 0.3451 - accuracy: 0.8581 - val_loss: 0.4917 - val_accuracy: 0.7938

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historyLstm.history['loss']
val_loss = historyLstm.history['val_loss']
epochs = [*range(10)]

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historyLstm.history['accuracy']
val_acc = historyLstm.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = LSTM_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
# Out:
# Accuracy : 0.793827971109652
# F1_Score : 0.7396351575456053

# %%
scores_model = []
scores_model.append({'Model': 'LSTM','Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Bidirectional LSTM

# %%
def Bi_LSTM(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    bilstm_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    bilstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return bilstm_model

# %%
bilstm_model = Bi_LSTM(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
bilstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 100)           1618800
# _________________________________________________________________
# bidirectional (Bidirectional (None, 30, 128)           84480
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,746,609
# Trainable params: 127,809
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historybilstm = bilstm_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 10, batch_size=64)
# Out:
# Epoch 1/10
# 96/96 [==============================] - 9s 33ms/step - loss: 0.5320 - accuracy: 0.7435 - val_loss: 0.5083 - val_accuracy: 0.7649
# Epoch 2/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.4731 - accuracy: 0.7837 - val_loss: 0.4923 - val_accuracy: 0.7774
# Epoch 3/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.4503 - accuracy: 0.7972 - val_loss: 0.4925 - val_accuracy: 0.7735
# Epoch 4/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.4331 - accuracy: 0.8102 - val_loss: 0.4778 - val_accuracy: 0.7840
# Epoch 5/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.4149 - accuracy: 0.8207 - val_loss: 0.4876 - val_accuracy: 0.7846
# Epoch 6/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.3969 - accuracy: 0.8261 - val_loss: 0.4839 - val_accuracy: 0.7892
# Epoch 7/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.3719 - accuracy: 0.8369 - val_loss: 0.5129 - val_accuracy: 0.7873
# Epoch 8/10
# 96/96 [==============================] - 2s 18ms/step - loss: 0.3434 - accuracy: 0.8537 - val_loss: 0.5305 - val_accuracy: 0.7853
# Epoch 9/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.3141 - accuracy: 0.8680 - val_loss: 0.5630 - val_accuracy: 0.7814
# Epoch 10/10
# 96/96 [==============================] - 1s 14ms/step - loss: 0.2841 - accuracy: 0.8819 - val_loss: 0.5461 - val_accuracy: 0.7892

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historybilstm.history['loss']
val_loss = historybilstm.history['val_loss']


#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historybilstm.history['accuracy']
val_acc = historybilstm.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = bilstm_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
# Out:
# Accuracy : 0.7892317793827971
# F1_Score : 0.7181738366988587

# %%
scores_model.append({'Model': 'Bi-directional','Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Bidirectional LSTM + Dropout

# %%
def Bi_LSTM_Drop(vocab_size, embedding_dim, maxlen, embeddings_matrix):
    bilstm_Drop_model = tf.keras.Sequential([ 
        # This is how you need to set the Embedding layer when using pre-trained embeddings
        tf.keras.layers.Embedding(VOCAB_SIZE+1, EMBEDDING_DIM, input_length=MAXLEN, weights=[EMBEDDINGS_MATRIX], trainable=False),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid'),
])
    bilstm_Drop_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return bilstm_Drop_model

# %%
bilstm_Drop_model = Bi_LSTM_Drop(VOCAB_SIZE, EMBEDDING_DIM, MAXLEN, EMBEDDINGS_MATRIX)
bilstm_Drop_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 30, 100)           1618800
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 100)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 30, 128)           84480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 128)           0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 64)                41216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,746,609
# Trainable params: 127,809
# Non-trainable params: 1,618,800
# _________________________________________________________________

# %%
historybilastm_drop = bilstm_Drop_model.fit(x = train_pad_trunc_seq, validation_data=(val_pad_trunc_seq, val_labels), y = train_labels, epochs = 10, batch_size=64)
# Out:
# Epoch 1/10
# 96/96 [==============================] - 10s 30ms/step - loss: 0.6121 - accuracy: 0.6762 - val_loss: 0.5125 - val_accuracy: 0.7643
# Epoch 2/10
# 96/96 [==============================] - 2s 19ms/step - loss: 0.5359 - accuracy: 0.7511 - val_loss: 0.4895 - val_accuracy: 0.7833
# Epoch 3/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.5185 - accuracy: 0.7588 - val_loss: 0.5007 - val_accuracy: 0.7741
# Epoch 4/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.5138 - accuracy: 0.7686 - val_loss: 0.4847 - val_accuracy: 0.7794
# Epoch 5/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.5113 - accuracy: 0.7757 - val_loss: 0.4824 - val_accuracy: 0.7833
# Epoch 6/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.5032 - accuracy: 0.7690 - val_loss: 0.4792 - val_accuracy: 0.7859
# Epoch 7/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.4926 - accuracy: 0.7829 - val_loss: 0.4764 - val_accuracy: 0.7892
# Epoch 8/10
# 96/96 [==============================] - 1s 15ms/step - loss: 0.4916 - accuracy: 0.7821 - val_loss: 0.4752 - val_accuracy: 0.7919
# Epoch 9/10
# 96/96 [==============================] - 2s 18ms/step - loss: 0.4869 - accuracy: 0.7808 - val_loss: 0.4834 - val_accuracy: 0.7866
# Epoch 10/10
# 96/96 [==============================] - 2s 16ms/step - loss: 0.4713 - accuracy: 0.7864 - val_loss: 0.4765 - val_accuracy: 0.7905

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
loss = historybilastm_drop.history['loss']
val_loss = historybilastm_drop.history['val_loss']

epochs = [*range(10)]

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
acc = historybilastm_drop.history['accuracy']
val_acc = historybilastm_drop.history['val_accuracy']

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

# %%
scores = bilstm_Drop_model.predict(val_pad_trunc_seq)
scores = np.around(scores, decimals=0)
print("Accuracy :", metrics.accuracy_score(val_labels,scores))
print("F1_Score :", metrics.f1_score(val_labels,scores))
# Out:
# Accuracy : 0.7905449770190414
# F1_Score : 0.7343880099916736

# %%
scores_model.append({'Model': 'Bi-directional_Dropout','Accuracy_Score': metrics.accuracy_score(val_labels,scores),
                    'F1_Score': metrics.f1_score(val_labels,scores)})

# %% [markdown]
# ## Result table

# %%
# Visualization of Results obtained from various Deep learning models
results = pd.DataFrame(scores_model).sort_values(by='F1_Score',ascending=False)
results.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_7d819_row0_col1, #T_7d819_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7d819_row1_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_7d819_row1_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_7d819_row2_col1, #T_7d819_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7d819_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy_Score</th>
#       <th class="col_heading level0 col2" >F1_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d819_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d819_row0_col0" class="data row0 col0" >LSTM</td>
#       <td id="T_7d819_row0_col1" class="data row0 col1" >0.793828</td>
#       <td id="T_7d819_row0_col2" class="data row0 col2" >0.739635</td>
#     </tr>
#     <tr>
#       <th id="T_7d819_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7d819_row1_col0" class="data row1 col0" >Bi-directional_Dropout</td>
#       <td id="T_7d819_row1_col1" class="data row1 col1" >0.790545</td>
#       <td id="T_7d819_row1_col2" class="data row1 col2" >0.734388</td>
#     </tr>
#     <tr>
#       <th id="T_7d819_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_7d819_row2_col0" class="data row2 col0" >Bi-directional</td>
#       <td id="T_7d819_row2_col1" class="data row2 col1" >0.789232</td>
#       <td id="T_7d819_row2_col2" class="data row2 col2" >0.718174</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Edit by Sira Haruethaipree
